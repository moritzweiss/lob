# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import os
base = os.path.dirname('/u/weim/lob/notebooks/performance_benchmark_strategies_damping_factors.ipynb')
parent_dir = os.path.dirname(base)

# %%
# %%capture 
# Define the time array
t = np.linspace(0, 10, 100)

# Define the exponential damping function
plt.figure(figsize=(10, 6))
plt.title('Exponential Damping Function')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.xticks(np.arange(min(t), max(t)+1, 1.0))  # Set x ticks at every integer

damping_factors = [0.25, 0.5, 1.0]

for c in damping_factors:

    y = np.exp(-c*t)
    # Plot the function
    plt.plot(t, y)

plt.grid(True)
plt.legend([f'c={c}' for c in damping_factors])
plt.show()

# %%
# %%capture 
# Define the time array
t = np.linspace(0, 1, 100)

# Define the exponential damping function
plt.figure(figsize=(10, 6))
plt.title('Root')
plt.xticks(np.arange(min(t), max(t)+1, 1.0))  # Set x ticks at every integer

powers = [1/2, 1/4, 1/8, 1/10]

for c in powers:

    y = np.power(t, c)
    # Plot the function
    plt.plot(t, y)

plt.grid(True)
plt.legend([f'c={c}' for c in powers])
plt.show()

# %%
d_025=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_c_0.25.csv')
d_050=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_c_0.5.csv')
d_100=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_c_1.0.csv')

print('damping c=0.25')
display(d_025) 

print('damping c=0.5')
display(d_050)

print('damping c=1.0')
display(d_100)
# Out:
# damping c=0.25
#    lots  noise_market  noise_sl  noise_linear_sl  flow_market  flow_sl  \
# 0    10         -0.60      0.56             0.59        -0.60     0.51
# 1    20         -1.05      0.13             0.22        -1.05    -0.05
# 2    30         -1.37     -0.31            -0.17        -1.37    -0.79
# 3    40         -1.75     -0.84            -0.62        -1.75    -1.61
#
#    flow_linear_sl
# 0            0.59
# 1            0.26
# 2           -0.16
# 3           -0.74
# damping c=0.5
#    lots  noise_market  noise_sl  noise_linear_sl  flow_market  flow_sl  \
# 0    10         -0.60      0.56             0.59        -0.60     0.51
# 1    20         -1.05      0.13             0.22        -1.05    -0.16
# 2    30         -1.37     -0.31            -0.17        -1.37    -1.12
# 3    40         -1.75     -0.84            -0.62        -1.75    -1.97
#
#    flow_linear_sl
# 0            0.58
# 1            0.21
# 2           -0.21
# 3           -0.75
# damping c=1.0
#    lots  noise_market  noise_sl  noise_linear_sl  flow_market  flow_sl  \
# 0    10         -0.60      0.56             0.59        -0.60     0.43
# 1    20         -1.05      0.13             0.22        -1.05    -0.49
# 2    30         -1.37     -0.31            -0.17        -1.37    -1.57
# 3    40         -1.75     -0.84            -0.62        -1.75    -2.59
#
#    flow_linear_sl
# 0            0.57
# 1            0.12
# 2           -0.43
# 3           -1.04
