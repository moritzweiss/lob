# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
import os
base = os.path.dirname('/u/weim/lob/notebooks/performance_benchmark_strategies_damping_factors.ipynb')
parent_dir = os.path.dirname(base)

# %%
noise=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_noise_c_1_sqrt.csv', index_col=0)
flow=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_flow_c_1_sqrt.csv', index_col=0)
strategic=pd.read_csv(f'{parent_dir}/results/performance_benchmarks_strategic_c_1_sqrt.csv', index_col=0)

print('noise')
display(noise)
print('flow')
display(flow)
print('strategic')
display(strategic)
# Out:
# noise
#       market_agent_mean  market_agent_std  sl_agent_mean  sl_agent_std  \
# lots
# 10                -0.51              0.44           0.32          1.75
# 40                -1.59              0.58          -1.27          2.35
#
#       linear_sl_agent_mean  linear_sl_agent_std
# lots
# 10                   -0.92                 2.25
# 40                   -2.43                 2.36
# flow
#       market_agent_mean  market_agent_std  sl_agent_mean  sl_agent_std  \
# lots
# 10                -0.51              0.44           0.12          1.89
# 40                -1.58              0.58          -3.34          2.20
#
#       linear_sl_agent_mean  linear_sl_agent_std
# lots
# 10                   -0.37                 2.01
# 40                   -2.29                 2.21
# strategic
#       market_agent_mean  market_agent_std  sl_agent_mean  sl_agent_std  \
# lots
# 10                -0.47              0.38          -3.31          5.13
# ...
